# %%
import pyttsx3
import time
names = ["sachin", "aditya", "souvik"]

for i in names:
    speaker = pyttsx3.init()
    speaker.say(f"Hello {i}, how are you today?")
    speaker.runAndWait()
    time.sleep(0.2)
    del speaker
